# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import dicom
import os
import scipy.ndimage
import matplotlib.pyplot as plt

from skimage import measure, morphology
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# Some constants 
INPUT_FOLDER = '../../../../kaggle-dsb-data/sample_images/'
patients = os.listdir(INPUT_FOLDER) # patients is a list of all 20 patient ids in sample_images
patients.sort()
print(patients)
# Out:
# ['00cba091fa4ad62cc3200a657aeb957e', '0a099f2549429d29b32f349e95fb2244', '0a0c32c9e08cc2ea76a71649de56be6d', '0a38e7597ca26f9374f8ea2770ba870d', '0acbebb8d463b4b9ca88cf38431aac69', '0b20184e0cd497028bdd155d9fb42dc9', '0bd0e3056cbf23a1cb7f0f0b18446068', '0c0de3749d4fe175b7a5098b060982a1', '0c37613214faddf8701ca41e6d43f56e', '0c59313f52304e25d5a7dcf9877633b1', '0c60f4b87afcb3e2dfa65abbbf3ef2f9', '0c98fcb55e3f36d0c2b6507f62f4c5f1', '0c9d8314f9c69840e25febabb1229fa4', '0ca943d821204ceb089510f836a367fd', '0d06d764d3c07572074d468b4cff954f', '0d19f1c627df49eb223771c28548350e', '0d2fcf787026fece4e57be167d079383', '0d941a3ad6c889ac451caf89c46cb92a', '0ddeb08e9c97227853422bd71a2a695e', '0de72529c30fe642bc60dcb75c87f6bd']

# %%
# Load the scans in given folder path
def load_scan(path):
    slices = [dicom.read_file(path + '/' + s) for s in os.listdir(path)] # slices becomes a list of all dicom images for each patient
    slices.sort(key = lambda x: int(x.InstanceNumber)) # sort all of the slices by their InstanceNumber (which determines their order)
    try: # try to find z location of the slice from ImagePositionPatient attribute
        slice_thickness = np.abs(slices[0].ImagePositionPatient[2] - slices[1].ImagePositionPatient[2]) 
    except: # otherwise, subtract one slice location from the other to get the thickness
        slice_thickness = np.abs(slices[0].SliceLocation - slices[1].SliceLocation)
        
    for s in slices: # for slice, make new attribute that is the slice's thickness 
        s.SliceThickness = slice_thickness
        
    return slices

# %%
first_patient = load_scan(INPUT_FOLDER + patients[3])
print(first_patient)
# Out:
# [(0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.283191673157709419896927743046301399420
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0020) Patient ID                          LO: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0050) Slice Thickness                     DS: '2.5'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.13148394979245937484165594540025668927189308811493143066650
# (0020, 000e) Series Instance UID                 UI: 2.25.53298563728906335585833752405238884704498238267638676785109
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0032) Image Position (Patient)            DS: ['-172.500000', '-176.100006', '27.959999']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 2.25.11642995668189613829999863683865722098177327703743652111991
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '27.959999'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.625000', '0.625000']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 US: 63536
# (0028, 1050) Window Center                       DS: '40'
# (0028, 1051) Window Width                        DS: '350'
# (0028, 1052) Rescale Intercept                   DS: '-1024'
# (0028, 1053) Rescale Slope                       DS: '1'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.302308300027108012668167264191936015732
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0020) Patient ID                          LO: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0050) Slice Thickness                     DS: '2.5'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.13148394979245937484165594540025668927189308811493143066650
# (0020, 000e) Series Instance UID                 UI: 2.25.53298563728906335585833752405238884704498238267638676785109
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '2'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0032) Image Position (Patient)            DS: ['-172.500000', '-176.100006', '25.459999']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 2.25.11642995668189613829999863683865722098177327703743652111991
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '25.459999'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.625000', '0.625000']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 US: 63536
# (0028, 1050) Window Center                       DS: '40'
# (0028, 1051) Window Width                        DS: '350'
# (0028, 1052) Rescale Intercept                   DS: '-1024'
# (0028, 1053) Rescale Slope                       DS: '1'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.153195127621339349637717354095172636620
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0020) Patient ID                          LO: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0050) Slice Thickness                     DS: '2.5'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.13148394979245937484165594540025668927189308811493143066650
# (0020, 000e) Series Instance UID                 UI: 2.25.53298563728906335585833752405238884704498238267638676785109
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '3'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0032) Image Position (Patient)            DS: ['-172.500000', '-176.100006', '22.959999']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 2.25.11642995668189613829999863683865722098177327703743652111991
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '22.959999'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.625000', '0.625000']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 US: 63536
# (0028, 1050) Window Center                       DS: '40'
# (0028, 1051) Window Width                        DS: '350'
# (0028, 1052) Rescale Intercept                   DS: '-1024'
# (0028, 1053) Rescale Slope                       DS: '1'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.209541869841062928856485353858110979224
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0020) Patient ID                          LO: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0050) Slice Thickness                     DS: '2.5'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.13148394979245937484165594540025668927189308811493143066650
# (0020, 000e) Series Instance UID                 UI: 2.25.53298563728906335585833752405238884704498238267638676785109
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '4'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0032) Image Position (Patient)            DS: ['-172.500000', '-176.100006', '20.459999']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 2.25.11642995668189613829999863683865722098177327703743652111991
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '20.459999'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.625000', '0.625000']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 US: 63536
# (0028, 1050) Window Center                       DS: '40'
# (0028, 1051) Window Width                        DS: '350'
# (0028, 1052) Rescale Intercept                   DS: '-1024'
# (0028, 1053) Rescale Slope                       DS: '1'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.30943521671177985396926521810068265241
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0020) Patient ID                          LO: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0050) Slice Thickness                     DS: '2.5'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.13148394979245937484165594540025668927189308811493143066650
# (0020, 000e) Series Instance UID                 UI: 2.25.53298563728906335585833752405238884704498238267638676785109
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '5'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0032) Image Position (Patient)            DS: ['-172.500000', '-176.100006', '17.959999']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 2.25.11642995668189613829999863683865722098177327703743652111991
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '17.959999'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.625000', '0.625000']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 US: 63536
# (0028, 1050) Window Center                       DS: '40'
# (0028, 1051) Window Width                        DS: '350'
# (0028, 1052) Rescale Intercept                   DS: '-1024'
# (0028, 1053) Rescale Slope                       DS: '1'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.172849474183586450435319740268254657276
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0020) Patient ID                          LO: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0050) Slice Thickness                     DS: '2.5'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.13148394979245937484165594540025668927189308811493143066650
# (0020, 000e) Series Instance UID                 UI: 2.25.53298563728906335585833752405238884704498238267638676785109
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '6'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0032) Image Position (Patient)            DS: ['-172.500000', '-176.100006', '15.459999']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 2.25.11642995668189613829999863683865722098177327703743652111991
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '15.459999'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.625000', '0.625000']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 US: 63536
# (0028, 1050) Window Center                       DS: '40'
# (0028, 1051) Window Width                        DS: '350'
# (0028, 1052) Rescale Intercept                   DS: '-1024'
# (0028, 1053) Rescale Slope                       DS: '1'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.256632223538439752795838676873497576721
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0020) Patient ID                          LO: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0050) Slice Thickness                     DS: '2.5'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.13148394979245937484165594540025668927189308811493143066650
# (0020, 000e) Series Instance UID                 UI: 2.25.53298563728906335585833752405238884704498238267638676785109
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '7'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0032) Image Position (Patient)            DS: ['-172.500000', '-176.100006', '12.959999']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 2.25.11642995668189613829999863683865722098177327703743652111991
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '12.959999'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.625000', '0.625000']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 US: 63536
# (0028, 1050) Window Center                       DS: '40'
# (0028, 1051) Window Width                        DS: '350'
# (0028, 1052) Rescale Intercept                   DS: '-1024'
# (0028, 1053) Rescale Slope                       DS: '1'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.218927303139552304309297229934761829559
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0020) Patient ID                          LO: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0050) Slice Thickness                     DS: '2.5'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.13148394979245937484165594540025668927189308811493143066650
# (0020, 000e) Series Instance UID                 UI: 2.25.53298563728906335585833752405238884704498238267638676785109
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '8'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0032) Image Position (Patient)            DS: ['-172.500000', '-176.100006', '10.459999']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 2.25.11642995668189613829999863683865722098177327703743652111991
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '10.459999'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.625000', '0.625000']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 US: 63536
# (0028, 1050) Window Center                       DS: '40'
# (0028, 1051) Window Width                        DS: '350'
# (0028, 1052) Rescale Intercept                   DS: '-1024'
# (0028, 1053) Rescale Slope                       DS: '1'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.256045538925037448516814112409445602394
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0020) Patient ID                          LO: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0050) Slice Thickness                     DS: '2.5'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.13148394979245937484165594540025668927189308811493143066650
# (0020, 000e) Series Instance UID                 UI: 2.25.53298563728906335585833752405238884704498238267638676785109
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '9'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0032) Image Position (Patient)            DS: ['-172.500000', '-176.100006', '7.959999']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 2.25.11642995668189613829999863683865722098177327703743652111991
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '7.959999'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.625000', '0.625000']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 US: 63536
# (0028, 1050) Window Center                       DS: '40'
# (0028, 1051) Window Width                        DS: '350'
# (0028, 1052) Rescale Intercept                   DS: '-1024'
# (0028, 1053) Rescale Slope                       DS: '1'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.48439081175620659291347841147697379816
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0020) Patient ID                          LO: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0050) Slice Thickness                     DS: '2.5'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.13148394979245937484165594540025668927189308811493143066650
# (0020, 000e) Series Instance UID                 UI: 2.25.53298563728906335585833752405238884704498238267638676785109
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '10'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0032) Image Position (Patient)            DS: ['-172.500000', '-176.100006', '5.459999']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 2.25.11642995668189613829999863683865722098177327703743652111991
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '5.459999'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.625000', '0.625000']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 US: 63536
# (0028, 1050) Window Center                       DS: '40'
# (0028, 1051) Window Width                        DS: '350'
# (0028, 1052) Rescale Intercept                   DS: '-1024'
# (0028, 1053) Rescale Slope                       DS: '1'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.26054265941847756300411259249605891007
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0020) Patient ID                          LO: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0050) Slice Thickness                     DS: '2.5'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.13148394979245937484165594540025668927189308811493143066650
# (0020, 000e) Series Instance UID                 UI: 2.25.53298563728906335585833752405238884704498238267638676785109
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '11'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0032) Image Position (Patient)            DS: ['-172.500000', '-176.100006', '2.959999']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 2.25.11642995668189613829999863683865722098177327703743652111991
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '2.959999'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.625000', '0.625000']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 US: 63536
# (0028, 1050) Window Center                       DS: '40'
# (0028, 1051) Window Width                        DS: '350'
# (0028, 1052) Rescale Intercept                   DS: '-1024'
# (0028, 1053) Rescale Slope                       DS: '1'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.42508514360552991205618339104390645362
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0020) Patient ID                          LO: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0050) Slice Thickness                     DS: '2.5'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.13148394979245937484165594540025668927189308811493143066650
# (0020, 000e) Series Instance UID                 UI: 2.25.53298563728906335585833752405238884704498238267638676785109
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '12'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0032) Image Position (Patient)            DS: ['-172.500000', '-176.100006', '0.459999']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 2.25.11642995668189613829999863683865722098177327703743652111991
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '0.459999'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.625000', '0.625000']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 US: 63536
# (0028, 1050) Window Center                       DS: '40'
# (0028, 1051) Window Width                        DS: '350'
# (0028, 1052) Rescale Intercept                   DS: '-1024'
# (0028, 1053) Rescale Slope                       DS: '1'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.330751019178340998437741048400355666293
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0020) Patient ID                          LO: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0050) Slice Thickness                     DS: '2.5'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.13148394979245937484165594540025668927189308811493143066650
# (0020, 000e) Series Instance UID                 UI: 2.25.53298563728906335585833752405238884704498238267638676785109
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '13'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0032) Image Position (Patient)            DS: ['-172.500000', '-176.100006', '-2.040001']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 2.25.11642995668189613829999863683865722098177327703743652111991
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '-2.040001'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.625000', '0.625000']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 US: 63536
# (0028, 1050) Window Center                       DS: '40'
# (0028, 1051) Window Width                        DS: '350'
# (0028, 1052) Rescale Intercept                   DS: '-1024'
# (0028, 1053) Rescale Slope                       DS: '1'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.225136681089311429308429915036407590260
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0020) Patient ID                          LO: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0050) Slice Thickness                     DS: '2.5'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.13148394979245937484165594540025668927189308811493143066650
# (0020, 000e) Series Instance UID                 UI: 2.25.53298563728906335585833752405238884704498238267638676785109
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '14'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0032) Image Position (Patient)            DS: ['-172.500000', '-176.100006', '-4.540001']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 2.25.11642995668189613829999863683865722098177327703743652111991
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '-4.540001'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.625000', '0.625000']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 US: 63536
# (0028, 1050) Window Center                       DS: '40'
# (0028, 1051) Window Width                        DS: '350'
# (0028, 1052) Rescale Intercept                   DS: '-1024'
# (0028, 1053) Rescale Slope                       DS: '1'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.296617569639081903246008018809076282067
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0020) Patient ID                          LO: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0050) Slice Thickness                     DS: '2.5'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.13148394979245937484165594540025668927189308811493143066650
# (0020, 000e) Series Instance UID                 UI: 2.25.53298563728906335585833752405238884704498238267638676785109
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '15'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0032) Image Position (Patient)            DS: ['-172.500000', '-176.100006', '-7.040001']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 2.25.11642995668189613829999863683865722098177327703743652111991
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '-7.040001'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.625000', '0.625000']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 US: 63536
# (0028, 1050) Window Center                       DS: '40'
# (0028, 1051) Window Width                        DS: '350'
# (0028, 1052) Rescale Intercept                   DS: '-1024'
# (0028, 1053) Rescale Slope                       DS: '1'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.109857056352159163481935855755242456717
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0020) Patient ID                          LO: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0050) Slice Thickness                     DS: '2.5'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.13148394979245937484165594540025668927189308811493143066650
# (0020, 000e) Series Instance UID                 UI: 2.25.53298563728906335585833752405238884704498238267638676785109
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '16'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0032) Image Position (Patient)            DS: ['-172.500000', '-176.100006', '-9.540001']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 2.25.11642995668189613829999863683865722098177327703743652111991
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '-9.540001'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.625000', '0.625000']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 US: 63536
# (0028, 1050) Window Center                       DS: '40'
# (0028, 1051) Window Width                        DS: '350'
# (0028, 1052) Rescale Intercept                   DS: '-1024'
# (0028, 1053) Rescale Slope                       DS: '1'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.326395247492815219820767350409846871819
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0020) Patient ID                          LO: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0050) Slice Thickness                     DS: '2.5'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.13148394979245937484165594540025668927189308811493143066650
# (0020, 000e) Series Instance UID                 UI: 2.25.53298563728906335585833752405238884704498238267638676785109
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '17'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0032) Image Position (Patient)            DS: ['-172.500000', '-176.100006', '-12.040001']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 2.25.11642995668189613829999863683865722098177327703743652111991
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '-12.040001'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.625000', '0.625000']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 US: 63536
# (0028, 1050) Window Center                       DS: '40'
# (0028, 1051) Window Width                        DS: '350'
# (0028, 1052) Rescale Intercept                   DS: '-1024'
# (0028, 1053) Rescale Slope                       DS: '1'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.68567250638039105186399841158037130578
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0020) Patient ID                          LO: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0050) Slice Thickness                     DS: '2.5'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.13148394979245937484165594540025668927189308811493143066650
# (0020, 000e) Series Instance UID                 UI: 2.25.53298563728906335585833752405238884704498238267638676785109
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '18'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0032) Image Position (Patient)            DS: ['-172.500000', '-176.100006', '-14.540001']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 2.25.11642995668189613829999863683865722098177327703743652111991
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '-14.540001'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.625000', '0.625000']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 US: 63536
# (0028, 1050) Window Center                       DS: '40'
# (0028, 1051) Window Width                        DS: '350'
# (0028, 1052) Rescale Intercept                   DS: '-1024'
# (0028, 1053) Rescale Slope                       DS: '1'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.166852250483629982190764507170223615803
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0020) Patient ID                          LO: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0050) Slice Thickness                     DS: '2.5'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.13148394979245937484165594540025668927189308811493143066650
# (0020, 000e) Series Instance UID                 UI: 2.25.53298563728906335585833752405238884704498238267638676785109
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '19'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0032) Image Position (Patient)            DS: ['-172.500000', '-176.100006', '-17.040001']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 2.25.11642995668189613829999863683865722098177327703743652111991
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '-17.040001'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.625000', '0.625000']
# ...
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 US: 63536
# (0028, 1050) Window Center                       DS: '40'
# (0028, 1051) Window Width                        DS: '350'
# (0028, 1052) Rescale Intercept                   DS: '-1024'
# (0028, 1053) Rescale Slope                       DS: '1'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.251805617899830260108500690671777349718
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0020) Patient ID                          LO: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0050) Slice Thickness                     DS: '2.5'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.13148394979245937484165594540025668927189308811493143066650
# (0020, 000e) Series Instance UID                 UI: 2.25.53298563728906335585833752405238884704498238267638676785109
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '105'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0032) Image Position (Patient)            DS: ['-172.500000', '-176.100006', '-232.040009']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 2.25.11642995668189613829999863683865722098177327703743652111991
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '-232.040009'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.625000', '0.625000']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 US: 63536
# (0028, 1050) Window Center                       DS: '40'
# (0028, 1051) Window Width                        DS: '350'
# (0028, 1052) Rescale Intercept                   DS: '-1024'
# (0028, 1053) Rescale Slope                       DS: '1'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.318956639736138938126372360133922662517
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0020) Patient ID                          LO: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0050) Slice Thickness                     DS: '2.5'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.13148394979245937484165594540025668927189308811493143066650
# (0020, 000e) Series Instance UID                 UI: 2.25.53298563728906335585833752405238884704498238267638676785109
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '106'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0032) Image Position (Patient)            DS: ['-172.500000', '-176.100006', '-234.540009']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 2.25.11642995668189613829999863683865722098177327703743652111991
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '-234.540009'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.625000', '0.625000']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 US: 63536
# (0028, 1050) Window Center                       DS: '40'
# (0028, 1051) Window Width                        DS: '350'
# (0028, 1052) Rescale Intercept                   DS: '-1024'
# (0028, 1053) Rescale Slope                       DS: '1'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.42860445031790387911757263011155558560
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0020) Patient ID                          LO: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0050) Slice Thickness                     DS: '2.5'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.13148394979245937484165594540025668927189308811493143066650
# (0020, 000e) Series Instance UID                 UI: 2.25.53298563728906335585833752405238884704498238267638676785109
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '107'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0032) Image Position (Patient)            DS: ['-172.500000', '-176.100006', '-237.040009']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 2.25.11642995668189613829999863683865722098177327703743652111991
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '-237.040009'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.625000', '0.625000']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 US: 63536
# (0028, 1050) Window Center                       DS: '40'
# (0028, 1051) Window Width                        DS: '350'
# (0028, 1052) Rescale Intercept                   DS: '-1024'
# (0028, 1053) Rescale Slope                       DS: '1'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.223206404781241573918586002322548036104
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0020) Patient ID                          LO: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0050) Slice Thickness                     DS: '2.5'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.13148394979245937484165594540025668927189308811493143066650
# (0020, 000e) Series Instance UID                 UI: 2.25.53298563728906335585833752405238884704498238267638676785109
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '108'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0032) Image Position (Patient)            DS: ['-172.500000', '-176.100006', '-239.540009']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 2.25.11642995668189613829999863683865722098177327703743652111991
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '-239.540009'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.625000', '0.625000']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 US: 63536
# (0028, 1050) Window Center                       DS: '40'
# (0028, 1051) Window Width                        DS: '350'
# (0028, 1052) Rescale Intercept                   DS: '-1024'
# (0028, 1053) Rescale Slope                       DS: '1'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.301125961031703480141241814928664519055
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0020) Patient ID                          LO: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0050) Slice Thickness                     DS: '2.5'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.13148394979245937484165594540025668927189308811493143066650
# (0020, 000e) Series Instance UID                 UI: 2.25.53298563728906335585833752405238884704498238267638676785109
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '109'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0032) Image Position (Patient)            DS: ['-172.500000', '-176.100006', '-242.040009']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 2.25.11642995668189613829999863683865722098177327703743652111991
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '-242.040009'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.625000', '0.625000']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 US: 63536
# (0028, 1050) Window Center                       DS: '40'
# (0028, 1051) Window Width                        DS: '350'
# (0028, 1052) Rescale Intercept                   DS: '-1024'
# (0028, 1053) Rescale Slope                       DS: '1'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes, (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.172417057944294031327929824889848320186
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0020) Patient ID                          LO: '0a38e7597ca26f9374f8ea2770ba870d'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0050) Slice Thickness                     DS: '2.5'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.13148394979245937484165594540025668927189308811493143066650
# (0020, 000e) Series Instance UID                 UI: 2.25.53298563728906335585833752405238884704498238267638676785109
# (0020, 0011) Series Number                       IS: '2'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '110'
# (0020, 0020) Patient Orientation                 CS: ''
# (0020, 0032) Image Position (Patient)            DS: ['-172.500000', '-176.100006', '-244.540009']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '1.000000', '0.000000']
# (0020, 0052) Frame of Reference UID              UI: 2.25.11642995668189613829999863683865722098177327703743652111991
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '-244.540009'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.625000', '0.625000']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 US: 63536
# (0028, 1050) Window Center                       DS: '40'
# (0028, 1051) Window Width                        DS: '350'
# (0028, 1052) Rescale Intercept                   DS: '-1024'
# (0028, 1053) Rescale Slope                       DS: '1'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes]

# %%
def get_pixels_hu(scans):
    image = np.stack([s.pixel_array for s in scans]) # image = 3D numpy array where each layer is a scan
    # Convert to int16 (from sometimes int16), 
    # should be possible as values should always be low enough (<32k)
    image = image.astype(np.int16)

    # Set outside-of-scan pixels to 0
    # The intercept is usually -1024, so air is approximately 0
    image[image == -2000] = 0
    
    # Convert to Hounsfield units (HU)
    intercept = scans[0].RescaleIntercept
    slope = scans[0].RescaleSlope
    
    if slope != 1:
        image = slope * image.astype(np.float64)
        image = image.astype(np.int16)
        
    image += np.int16(intercept)
    
    return np.array(image, dtype=np.int16)

# %% [markdown]
# ## Meaning of .RescaleIntercept and .RescaleSlope
# Every CT image will have this attribute, and you can use them to scale the stored pixel values to hounsfield units (which will help determine the type of material for each pixel in the CT scan). Find explanations [here](https://blog.kitware.com/dicom-rescale-intercept-rescale-slope-and-itk/) and [here](http://stackoverflow.com/questions/10193971/rescale-slope-and-rescale-intercept).

# %%
def resample(image, scan, new_spacing=[1,1,1]):
    # Determine current pixel spacing
    spacing = map(float, ([scan[0].SliceThickness] + scan[0].PixelSpacing)) # normally the PixelSpacing attribute will only contain spacing for the [x, y], that is why you need to add z (or the slice thickness)
    spacing = np.array(list(spacing)) # this gives pixel spacing in terms of [z, x, y] where x=y

    resize_factor = spacing / new_spacing
    new_real_shape = image.shape * resize_factor
    new_shape = np.round(new_real_shape) # the issue is that if it rounds well for this case, does it round well for all the cases? if it doesnt how will you figure out the best way for it to round to the same resolution for all images if they round differently
    real_resize_factor = new_shape / image.shape
    new_spacing = spacing / real_resize_factor
    
    image = scipy.ndimage.interpolation.zoom(image, real_resize_factor)
    
    return image, new_spacing

# %%
for patient in patients:
    patient_scan = load_scan(INPUT_FOLDER + patient) # load all the dicom scans for the patient, including the slice thickness
    patient_pixels = get_pixels_hu(patient_scan) # take patients scans, return single 3D numpy array that contains hounsfield unit pixels for each scan
    resampled_pixels, real_spacing = resample(patient_pixels, patient_scan, new_spacing=[1, 1, 1])
